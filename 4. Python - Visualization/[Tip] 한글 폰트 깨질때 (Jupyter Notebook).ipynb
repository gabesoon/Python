# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 불필요한 경고 표시 생략
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ## 데이터프레임 로드

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')
df
# Out:
#       지역             규모    연도   월   분양가
# 0     서울          60㎡이하  2015  10  5652
# 1     서울    60㎡초과 85㎡이하  2015  10  5882
# 2     서울   85㎡초과 102㎡이하  2015  10  5721
# 3     서울         102㎡초과  2015  10  5879
# 4     인천          60㎡이하  2015  10  3488
# ...   ..            ...   ...  ..   ...
# 3288  경남    60㎡초과 85㎡이하  2020   2  3065
# 3289  경남   85㎡초과 102㎡이하  2020   2  3247
# 3290  제주          60㎡이하  2020   2  4039
# 3291  제주    60㎡초과 85㎡이하  2020   2  3962
# 3292  제주         102㎡초과  2020   2  3601
#
# [3293 rows x 5 columns]

# %%
df.plot();

# %% [markdown]
# 한글 데이터 깨짐 현상이 발견 될 수 있다.
# 만약 한글 깨짐 현상이 발견된다면, 아래의 방법을 활용하면 된다.

# %% [markdown]
# ## 한글 폰트 깨짐 현상 해결방법
#
# - 원하는 폰트가 pc에 설치되어 있어야 한다.
# - 네이버 폰트 오픈 소스 페이지(https://hangeul.naver.com/2017/nanum)
# - 현재 작업 페이지의 폰트만 바꾸는 방법(방법1) 과 영구 적용(방법2) 가 있다.

# %% [markdown]
# ## 방법 1. 일시적 변경 (해당 노트북 한정)

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline


# 사용자 운영체제 확인
import platform
platform.system()
# Out:
# 'Windows'

# %%
# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
df.plot();

# %% [markdown]
# ## 방법 2. 영구적 해결 (시스템 설정 변경)

# %% [markdown]
# ## STEP 1. 적용을 희망하는 폰트의 영어이름을 확인한다.
#
# - 아래의 코드를 실행 후 `ctrl + F` 로 원하는 폰트명을 찾는다.
# - 여기서는 Malgun Gothic 을 적용하겠다.

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')

font_list[:]
# Out:
# ['C:\\Windows\\Fonts\\ALGER.TTF',
#  'C:\\Windows\\Fonts\\BRADHITC.TTF',
#  'C:\\Windows\\Fonts\\LTYPEBO.TTF',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\HMKMAMI.TTF',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\ARIALN.TTF',
#  'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  'C:\\Windows\\Fonts\\H2SA1M.TTF',
#  'C:\\Windows\\Fonts\\marlett.ttf',
#  'C:\\Windows\\Fonts\\RAVIE.TTF',
#  'C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF',
#  'C:\\Windows\\Fonts\\NanumGothicBold.ttf',
# ...

# %% [markdown]
# ## STEP 2. 한글 폰트 영구 등록
#
# - 지정한 폰트를 영구적으로 Jupyter Notebook에서 인식하고 사용하도록 지정해야 한다.
# - 설정 파일 위치를 확인한다.

# %%
import matplotlib as mpl
print (mpl.matplotlib_fname())
# Out:
# C:\Users\HB\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# ### STEP 2-1. 설정 파일 오픈 & 설정 변경

# %% [markdown]
# - 위에 출력된 경로의 matplotlibrc 라는 파일이 설정 파일이다.
# - 메모장 or 워드패드로 열어서 설정 변경을 해줘야 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```python
# # font.family : sans-serif
# ```
# 부분을 다음과 같이 바꿔 준다.
# ```python
# # font.family : Malgun Gothic
# ```

# %% [markdown]
# ## 추가 설정 (음수일때 깨짐 현상 해결)
#
# - 한글 적용을 한 뒤에도 값이 '음수' 인 경우, **-** 값이 깨지는 현상이 발생한다.

# %% [markdown]
# 동일 파일에서  axes.unicode_minus 를 찾아서 True인 값을 False로 바꿔 준다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 결과 확인
#
# - Kernel 을 재시작 한뒤 다시 실행하여 확인

# %%
df.plot()
# Out:
# <AxesSubplot:>
